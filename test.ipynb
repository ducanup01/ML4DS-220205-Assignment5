# %%
import torch
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: True

# %%
print("GPU count:", torch.cuda.device_count())
# Out:
# GPU count: 2

# %%
for i in range(torch.cuda.device_count()):
    print(f"GPU {i}:", torch.cuda.get_device_name(i))
# Out:
# GPU 0: NVIDIA GeForce RTX 5060 Ti
# GPU 1: NVIDIA GeForce RTX 5060 Ti

# %%
print(torch.cuda.get_device_properties(0))
# Out:
# _CudaDeviceProperties(name='NVIDIA GeForce RTX 5060 Ti', major=12, minor=0, total_memory=15848MB, multi_processor_count=36, uuid=d7c48a11-498d-991c-59de-ec2cdcfc5651, pci_bus_id=0, pci_device_id=16, pci_domain_id=0, L2_cache_size=32MB)
